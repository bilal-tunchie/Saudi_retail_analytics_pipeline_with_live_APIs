# %% [markdown]
# #API Keys

# %%
HASDATA_AMAZON_SEARCH_KEY = "*******************"
CALENDARIFIC_KEY          = "********************"

# %% [markdown]
# #Catalog & Schema targets

# %%
# Unity Catalog targets — this is where Delta tables land
CATALOG        = "saudi_retail_catalog"
BRONZE_SCHEMA  = "bronze"
SILVER_SCHEMA  = "silver"
GOLD_SCHEMA    = "gold"

# Full table references
BRONZE_PRODUCTS           = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_product"
BRONZE_ORDERS             = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_orders"
BRONZE_WEATHER            = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_weather"
BRONZE_HOLIDAYS           = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_holidays"
BRONZE_ORDERS_ENRICHED    = f"{CATALOG}.{BRONZE_SCHEMA}.bronze_orders_enriched"

# %% [markdown]
# #Constants

# %%
from datetime import datetime

SNAPSHOT_DATE = datetime.today().strftime("%d-%m-%Y")

HOLIDAYS_VOLUME = "/Volumes/saudi_retail_catalog/bronze/holidays_volume"

ORDERS_VOLUME = "/Volumes/saudi_retail_catalog/bronze/orders_volume"

PRODUCTS_VOLUME = "/Volumes/saudi_retail_catalog/bronze/products_volume/hasdata_products/"

SAUDI_CITIES = [
    {"city": "Riyadh",  "lat": 24.7136, "lon": 46.6753},
    {"city": "Jeddah",  "lat": 21.3891, "lon": 39.8579},
    {"city": "Dammam",  "lat": 26.4207, "lon": 50.0888},
    {"city": "Mecca",   "lat": 21.3891, "lon": 39.8579},
    {"city": "Madina",  "lat": 24.5247, "lon": 39.5692},
    {"city": "Khobar",  "lat": 26.2172, "lon": 50.1971},
]

PRODUCTS_CATEGORIES = [
    "Electronics",
    "Laptops",
    "Gaming",
    "Fashion_Men",
    "Fashion_Women",
    "Home",
    "Beauty",
    "Grocery",
    "Sports",
    "Books",
]
